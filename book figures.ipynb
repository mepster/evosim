# %%
from importlib import reload
import evosim
reload(evosim); None

N1 = 1e6

# %% [markdown]
# # Chapter 3. An *in silico* example

# %%
# selection alone
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = False # False = NO MUTATION

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01
args.minMu=2

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:20.0 is high >= 20.0 (fixation CAN happen in one epoch (ignoring mutation))

# %%
# mutation-selection balance, M2
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01
args.minMu = 2

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:20.0 is high >= 20.0 (fixation CAN happen in one epoch (ignoring mutation))

# %%
# mutation-selection balance, M3
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 3

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:20.0 is high >= 20.0 (fixation CAN happen in one epoch (ignoring mutation))

# %%
# mutation-selection balance, M4
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 4

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:20.0 is high >= 20.0 (fixation CAN happen in one epoch (ignoring mutation))

# %%
# mutation-selection balance, M3
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.01


# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:10.0 is low < 20.0 (fixation WON'T usually happen in one epoch)

# %%
# mutation-selection balance, M3
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 3

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.01


# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:10.0 is low < 20.0 (fixation WON'T usually happen in one epoch)

# %%
# mutation-selection balance, M3
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 4

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.01


# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:10.0 is low < 20.0 (fixation WON'T usually happen in one epoch)

# %%
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = True

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:10.0 is low < 20.0 (fixation WON'T usually happen in one epoch)

# %%
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = False

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:10.0 is low < 20.0 (fixation WON'T usually happen in one epoch)

# %%
args = evosim.default_args.copy()

args.s = 0.1 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e2 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = False

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:100000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:10.0 is low < 20.0 (fixation WON'T usually happen in one epoch)

# %%
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e4 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = False

# Re-run multiple times (Cmd-return) with different parameters.
# experiment 1: change N between 1e2 and 1e9, re-run multple times (Cmd-return) 
# experiment 2: compare large N to N=-1 (which means infinite population)

# Notice how often A or B "fixes" (reaches 100% frequency) in small vs large populations, and over time
# The opposite of "fix" is "go extinct" (reach 0% frequency)

# Now try varying T. With long T like 1e4, there is plenty of time for eventual fixation/extinction
# With T=1e2 we rarely get close to fixation/extinction (with drift only, no selection)

evosim.evosim(args)
# Out:
# Ns:10000.0 is high >= 10.0 (selection is STRONG relative to drift)
# sT:100.0 is high >= 20.0 (fixation CAN happen in one epoch (ignoring mutation))

# %% [markdown]
# # Chapter 4. Clades
