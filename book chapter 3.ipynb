# %%
from importlib import reload
import evosim
reload(evosim); None

N1 = 1e7

# %% [markdown]
# # Chapter 3. An *in silico* example

# %%
# selection alone
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = False # False = NO MUTATION

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01
args.minMu=2


evosim.evosim(args)

# %%
# mutation-selection balance, M2
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01
args.minMu = 2


evosim.evosim(args)

# %%
# mutation-selection balance, M3
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 3

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01


evosim.evosim(args)

# %%
# mutation-selection balance, M4
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 4

args.N = N1
args.T = 2e3 # 1e3
args.aToB = 0.01


evosim.evosim(args)

# %%
# 
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.01


evosim.evosim(args)

# %%
# 
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 3

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.01


evosim.evosim(args)

# %%
# 
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 4

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.01


evosim.evosim(args)

# %%
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = True


evosim.evosim(args)

# %%
args = evosim.default_args.copy()

args.s = 0.01 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e3 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = False


evosim.evosim(args)

# %%
args = evosim.default_args.copy()

args.s = 0.1 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e2 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = False


evosim.evosim(args)

# %%
args = evosim.default_args.copy()

args.s = 0.001 # NO SELECTION when s=0.0
args.includeMutation = True # False = NO MUTATION
args.minMu = 2
args.numClades = 3

args.N = N1
args.T = 1e4 # 1e3
args.numEpochs = 5
args.aToB = 0.001
args.plotAB = False


evosim.evosim(args)

# %%
# drift alone

# Drift alone, hiding B, multiple runs together
args = evosim.default_args.copy()

args.seed = 3863068465
args.s = 0.0 # s = 0.001
args.includeMutation = False # False = no mutation

args.N = 1e5
args.T = 1e3
args.numEpochs = 1

args.numClades = 1
args.numRuns = 10
#args.plotAB = False
#args.hideB = True

args.numPops = 1

evosim.evosim(args)

# %%
# Drift alone, hiding B, multiple runs together
args = evosim.default_args.copy()

args.seed = 3863068465
args.s = 0.0 # s = 0.001
args.includeMutation = False # False = no mutation

args.N = 1e4
args.T = 1e3
args.numEpochs = 1

args.numClades = 1
args.numRuns = 10
#args.plotAB = False
#args.hideB = True

args.numPops = 1

evosim.evosim(args)

# %%
from importlib import reload
import evosim
reload(evosim); None


# Drift alone, hiding B, multiple runs together
args = evosim.default_args.copy()

args.seed = 2544742651
args.s = 0.0 # s = 0.001
args.includeMutation = False # False = no mutation

args.N = 1e3
args.T = 1e3
args.numEpochs = 1

args.numClades = 1
args.numRuns = 10
#args.plotAB = False
#args.hideB = True

args.numPops = 1

evosim.evosim(args)
